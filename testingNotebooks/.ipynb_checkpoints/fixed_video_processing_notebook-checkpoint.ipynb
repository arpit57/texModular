# %%
import cv2
from datetime import datetime
from ultralytics import YOLO
from utilities import is_inside, draw_detections_on_frame

model = YOLO('handDetection.pt')

class State:
    WAIT_FOR_PICKUP = 1
    WAIT_FOR_DROP = 2

def is_entering_from_side(box, sides, frame_width, frame_height):
    x_center, y_center = (box[0] + box[2]) / 2, (box[1] + box[3]) / 2
    entering_from_sides = {
        'left': x_center <= frame_width * 0.25,
        'right': x_center >= frame_width * 0.75,
        'top': y_center <= frame_height * 0.25,
        'bottom': y_center >= frame_height * 0.75
    }
    return any(entering_from_sides[side] for side in sides)


def draw_side_of_rectangle(frame, rect_coords, side, color, thickness):
    p1, p2 = rect_coords
    if side == 'left':
        cv2.line(frame, p1, (p1[0], p2[1]), color, thickness)
    elif side == 'right':
        cv2.line(frame, (p2[0], p1[1]), p2, color, thickness)
    elif side == 'top':
        cv2.line(frame, p1, (p2[0], p1[1]), color, thickness)
    elif side == 'bottom':
        cv2.line(frame, (p1[0], p2[1]), p2, color, thickness)


def process_video(video_url, pickup_coords, drop_coords, pickup_sides, drop_sides, output_path):
    cap = cv2.VideoCapture(video_url)
    if not cap.isOpened():
        raise ValueError(f"Couldn't open video stream from URL: {video_url}")

    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    original_fps = int(cap.get(cv2.CAP_PROP_FPS))

    frame_count = 0
    state = State.WAIT_FOR_PICKUP
    count = 0
    hand_was_in_drop = False

    # Define the codec and create VideoWriter object to write the output video
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, original_fps, (width, height))

    while True:
        ret, frame = cap.read()
        if not ret:
            print("Stream ended.")
            break

        if frame_count % (original_fps // 5) == 0:  # Process at a reduced frame rate
            results = model(frame, conf=0.05, iou=0.1)
            for box_data in results[0].boxes.data.cpu().numpy():
                box_data = list(map(int, box_data[:4]))  # Convert map object to list
                if is_inside(box_data, pickup_coords) and is_entering_from_side(box_data, pickup_sides, width, height):
                    hand_detected_in_pickup = True
                    break
            else:
                hand_detected_in_pickup = False
            
            for box_data in results[0].boxes.data.cpu().numpy():
                box_data = list(map(int, box_data[:4]))  # Convert map object to list
                if is_inside(box_data, drop_coords) and is_entering_from_side(box_data, drop_sides, width, height):
                    hand_detected_in_drop = True
                    break
            else:
                hand_detected_in_drop = False

            for side in pickup_sides:
                draw_side_of_rectangle(frame, pickup_coords, side, (0, 0, 255), 2)
            for side in drop_sides:
                draw_side_of_rectangle(frame, drop_coords, side, (0, 0, 255), 2)
            
            # Update states and count
            if state == State.WAIT_FOR_PICKUP and hand_detected_in_pickup:
                state = State.WAIT_FOR_DROP

            if state == State.WAIT_FOR_DROP and hand_detected_in_drop and not hand_was_in_drop:
                hand_was_in_drop = True

            if hand_was_in_drop and not hand_detected_in_drop:
                count += 1
                state = State.WAIT_FOR_PICKUP
                hand_was_in_drop = False

            # Drawing and annotations on the frame
            for box_data in results[0].boxes.data.cpu().numpy():
                frame = draw_detections_on_frame(frame, box_data, results[0].names)

            cv2.putText(frame, f"Count: {count}", (width - 150, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            cv2.putText(frame, f"Pickup: {hand_detected_in_pickup}", (width - 150, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)
            cv2.putText(frame, f"Drop: {hand_detected_in_drop}", (width - 150, 90), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)
            cv2.putText(frame, f"Was in Drop: {hand_was_in_drop}", (width - 150, 120), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)
            cv2.putText(frame, f"State: {state}", (width - 150, 150), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)
            cv2.rectangle(frame, pickup_coords[0], pickup_coords[1], (0, 255, 0), 2)
            cv2.rectangle(frame, drop_coords[0], drop_coords[1], (0, 255, 0), 2)

            out.write(frame)  # Save the frame to the output video file

        frame_count += 1

    cap.release()
    out.release()  # Make sure to release the VideoWriter object

# %%
# # Example usage
# video_url = 'videos/testVideo2.mp4'
# pickup_coords = [[5, 10], [120, 140]]
# drop_coords = [[240, 60], [450, 190]]
# pickup_sides = ['right', 'bottom']
# drop_sides = ['bottom']
# output_path = 'output/output.mp4'

# process_video(video_url, pickup_coords, drop_coords, pickup_sides, drop_sides, output_path)

# %%
video_url = 'videos/testVideo2.mp4'
pickup_coords = [[5, 10], [120, 140]]
drop_coords = [[240, 60], [450, 190]]
pickup_sides = ['right', 'bottom']
drop_sides = ['bottom']
output_path = 'output/output.mp4'

# %%
import cv2
from ultralytics import YOLO
from utilities import is_inside, draw_detections_on_frame

# %%
model = YOLO('handDetection.pt')

class State:
    WAIT_FOR_PICKUP = 1
    WAIT_FOR_DROP = 2

# Function to determine if a box enters or exits from a specified side
def is_entering_from_side(box, sides, frame_width, frame_height):
    x_center, y_center = (box[0] + box[2]) / 2, (box[1] + box[3]) / 2
    entering_from_sides = {
        'left': x_center <= frame_width * 0.25,
        'right': x_center >= frame_width * 0.75,
        'top': y_center <= frame_height * 0.25,
        'bottom': y_center >= frame_height * 0.75
    }
    return any(entering_from_sides[side] for side in sides)

# Function to draw and highlight regions
def draw_and_highlight_regions(frame, coords, sides, roiColor, sideColor, thickness=2, highlight_thickness=3):
    # Draw rectangle
    cv2.rectangle(frame, tuple(coords[0]), tuple(coords[1]), roiColor, thickness)
    # Highlight sides
    for side in sides:
        if side == 'left':
            cv2.line(frame, (coords[0][0], coords[0][1]), (coords[0][0], coords[1][1]), sideColor, highlight_thickness)
        elif side == 'right':
            cv2.line(frame, (coords[1][0], coords[0][1]), (coords[1][0], coords[1][1]), sideColor, highlight_thickness)
        elif side == 'top':
            cv2.line(frame, (coords[0][0], coords[0][1]), (coords[1][0], coords[0][1]), sideColor, highlight_thickness)
        elif side == 'bottom':
            cv2.line(frame, (coords[0][0], coords[1][1]), (coords[1][0], coords[1][1]), sideColor, highlight_thickness)

def process_video(video_url, pickup_coords, drop_coords, pickup_sides, drop_sides, out_frames):
    cap = cv2.VideoCapture(video_url)
    if not cap.isOpened():
        raise ValueError(f"Couldn't open video stream from URL: {video_url}")

    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    original_fps = int(cap.get(cv2.CAP_PROP_FPS))
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # or 'XVID'
    out = cv2.VideoWriter(output_path, fourcc, original_fps, (width, height))
    
    frame_count = 0
    state = State.WAIT_FOR_PICKUP
    count = 0
    hand_was_in_drop = False

    last_count = -1
    last_time = None
    cycle_time = 0.0

    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                print("Stream ended.")
                break

            if frame_count % (original_fps // 5) == 0:  # limiting to 5 fps
                results = model(frame, conf=0.05, iou=0.2)
                hand_detected_in_pickup = any(is_entering_from_side(list(map(int, box_data[:4])), pickup_sides, width, height) for box_data in results[0].boxes.data.cpu().numpy())
                hand_detected_in_drop = any(is_entering_from_side(list(map(int, box_data[:4])), drop_sides, width, height) for box_data in results[0].boxes.data.cpu().numpy())



                # State and count update logic
                if state == State.WAIT_FOR_PICKUP and hand_detected_in_pickup:
                    state = State.WAIT_FOR_DROP

                if state == State.WAIT_FOR_DROP and hand_detected_in_drop:
                    hand_was_in_drop = True

                if hand_was_in_drop and not hand_detected_in_drop:
                    count += 1
                    state = State.WAIT_FOR_PICKUP
                    hand_was_in_drop = False
                for box_data in results[0].boxes.data.cpu().numpy():
                    frame = draw_detections_on_frame(frame, box_data, results[0].names)
    
                cv2.putText(frame, f"Count: {count}", (width - 150, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                cv2.putText(frame, f"Pickup: {hand_detected_in_pickup}", (width - 150, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)
                cv2.putText(frame, f"Drop: {hand_detected_in_drop}", (width - 150, 90), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)
                cv2.putText(frame, f"Was in Drop: {hand_was_in_drop}", (width - 150, 120), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)
                cv2.putText(frame, f"State: {state}", (width - 150, 150), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)
                cv2.rectangle(frame, pickup_coords[0], pickup_coords[1], (0, 255, 0), 2)
                cv2.rectangle(frame, drop_coords[0], drop_coords[1], (0, 255, 0), 2)
                draw_and_highlight_regions(frame, pickup_coords, pickup_sides, (0, 255, 0), (0, 0, 255))
                draw_and_highlight_regions(frame, drop_coords, drop_sides, (0, 255, 0), (0, 0, 255))

                out.write(frame)  # Save the frame to the output video file

            frame_count += 1

    finally:
        cap.release()
        out.release()
        cv2.destroyAllWindows()

# %%
model = YOLO('handDetection.pt')
class State:
    WAIT_FOR_PICKUP = 1
    WAIT_FOR_DROP = 2

def is_entering_from_side(box, region, sides):
    x_center, y_center = (box[0] + box[2]) / 2, (box[1] + box[3]) / 2
    region_width = region[1][0] - region[0][0]
    region_height = region[1][1] - region[0][1]
    region_x_center = (region[0][0] + region[1][0]) / 2
    region_y_center = (region[0][1] + region[1][1]) / 2

    entering_from_sides = {
        'left': x_center <= region_x_center - region_width * 0.25,
        'right': x_center >= region_x_center + region_width * 0.25,
        'top': y_center <= region_y_center - region_height * 0.25,
        'bottom': y_center >= region_y_center + region_height * 0.25
    }
    return any(entering_from_sides[side] for side in sides)

def process_video(video_url, pickup_coords, drop_coords, pickup_sides, drop_sides, output_path):
    model = YOLO('handDetection.pt')
    cap = cv2.VideoCapture(video_url)
    if not cap.isOpened():
        raise ValueError(f"Couldn't open video stream from URL: {video_url}")
  
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                break

            results = model(frame, conf=0.05, iou=0.2)

            for box_data in results[0].boxes.data.cpu().numpy():
                box = list(map(int, box_data[:4]))
                entering_pickup = is_entering_from_side(box, pickup_coords, pickup_sides)
                entering_drop = is_entering_from_side(box, drop_coords, drop_sides)

                label_pickup = f"Entering Pickup: {entering_pickup}"
                label_drop = f"Entering Drop: {entering_drop}"
                cv2.putText(frame, label_pickup, (box[0], box[1]-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)
                cv2.putText(frame, label_drop, (box[0], box[1]-25), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)
                cv2.rectangle(frame, (box[0], box[1]), (box[2], box[3]), (0, 255, 0), 2)

            out.write(frame)

    finally:
        cap.release()
        out.release()
        cv2.destroyAllWindows()

# Example usage
video_url = 'videos/testVideo2.mp4'
output_path = 'output/test_output.mp4'
pickup_coords = [[5, 10], [120, 140]]  # Define pickup ROI coordinates
drop_coords = [[240, 60], [450, 190]]  # Define drop ROI coordinates
pickup_sides = ["right", "bottom"]      # Define pickup sides to check
drop_sides = ["bottom"]                 # Define drop sides to check
process_video(video_url, pickup_coords, drop_coords, pickup_sides, drop_sides, output_path)

# %%
# Example usage
video_url = 'videos/testVideo2.mp4'
pickup_coords = [[5, 10], [120, 140]]
drop_coords = [[240, 60], [450, 190]]
pickup_sides = ['right', 'bottom']
drop_sides = ['bottom']
output_path = 'output/output.mp4'

process_video(video_url, pickup_coords, drop_coords, pickup_sides, drop_sides, output_path)

# %%
# Function to draw and highlight regions
def draw_and_highlight_regions(frame, coords, sides, roiColor, sideColor, thickness=2, highlight_thickness=3):
    # Draw rectangle
    cv2.rectangle(frame, tuple(coords[0]), tuple(coords[1]), roiColor, thickness)
    # Highlight sides
    if 'left' in sides:
        cv2.line(frame, (coords[0][0], coords[0][1]), (coords[0][0], coords[1][1]), sideColor, highlight_thickness)
    if 'right' in sides:
        cv2.line(frame, (coords[1][0], coords[0][1]), (coords[1][0], coords[1][1]), sideColor, highlight_thickness)
    if 'top' in sides:
        cv2.line(frame, (coords[0][0], coords[0][1]), (coords[1][0], coords[0][1]), sideColor, highlight_thickness)
    if 'bottom' in sides:
        cv2.line(frame, (coords[0][0], coords[1][1]), (coords[1][0], coords[1][1]), sideColor, highlight_thickness)

# Initialize video capture and writer
cap = cv2.VideoCapture(video_url)
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_path, fourcc, 20.0, (int(cap.get(3)), int(cap.get(4))))

# Process video
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Draw and highlight pickup region in green
    draw_and_highlight_regions(frame, pickup_coords, pickup_sides, (0, 255, 0), (0, 0, 255))
    # Draw and highlight drop region in red
    draw_and_highlight_regions(frame, drop_coords, drop_sides, (0, 255, 0), (0, 0, 255))

    out.write(frame)

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()

# %%
import cv2
from ultralytics import YOLO

# %%
model = YOLO('handDetection.pt').to('cpu')

def is_entering_from_side(box, region, sides):
    x_center, y_center = (box[0] + box[2]) / 2, (box[1] + box[3]) / 2
    region_width = region[1][0] - region[0][0]
    region_height = region[1][1] - region[0][1]
    region_x_center = (region[0][0] + region[1][0]) / 2
    region_y_center = (region[0][1] + region[1][1]) / 2

    entering_from_sides = {
        'left': x_center < region[0][0],  # Entering from left if center is to the left of the region
        'right': x_center > region[1][0],  # Entering from right if center is to the right of the region
        'top': y_center < region[0][1],  # Entering from top if center is above the region
        'bottom': y_center > region[1][1]  # Entering from bottom if center is below the region
    }
    return any(entering_from_sides[side] for side in sides)

def process_video(video_url, pickup_coords, drop_coords, pickup_sides, drop_sides, output_path):
    cap = cv2.VideoCapture(video_url)
    if not cap.isOpened():
        raise ValueError(f"Couldn't open video stream from URL: {video_url}")

    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                break

            results = model(frame, conf=0.05, iou=0.2)

            for box_data in results[0].boxes.data.cpu().numpy():
                box = list(map(int, box_data[:4]))
                entering_pickup = is_entering_from_side(box, pickup_coords, pickup_sides)
                entering_drop = is_entering_from_side(box, drop_coords, drop_sides)
                cv2.putText(frame, f"entering_pickup: {str(entering_pickup)}", (width - 150, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)
                cv2.putText(frame, f"entering_drop: {str(entering_drop)}", (width - 150, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

            out.write(frame)

    finally:
        cap.release()
        out.release()
        cv2.destroyAllWindows()

# Example usage
video_url = 'videos/testVideo2.mp4'
pickup_coords = [[5, 10], [120, 140]]
drop_coords = [[240, 60], [450, 190]]
pickup_sides = ['right', 'bottom']
drop_sides = ['bottom']
output_path = 'output/output.mp4'

process_video(video_url, pickup_coords, drop_coords, pickup_sides, drop_sides, output_path)
# Out:
# 0: 384x640 1 Human hand, 26.5ms
# Speed: 2.2ms preprocess, 26.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 28.4ms
# Speed: 1.2ms preprocess, 28.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.8ms
# Speed: 1.3ms preprocess, 26.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.9ms
# Speed: 1.2ms preprocess, 26.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.1ms
# Speed: 1.2ms preprocess, 26.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.2ms
# Speed: 1.2ms preprocess, 26.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 27.2ms
# Speed: 1.2ms preprocess, 27.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.3ms
# Speed: 1.2ms preprocess, 26.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.4ms
# Speed: 1.2ms preprocess, 26.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 31.3ms
# Speed: 1.2ms preprocess, 31.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.9ms
# Speed: 1.2ms preprocess, 26.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.7ms
# Speed: 1.1ms preprocess, 26.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.0ms
# Speed: 1.1ms preprocess, 21.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.7ms
# Speed: 1.1ms preprocess, 19.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.9ms
# Speed: 1.4ms preprocess, 18.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.8ms
# Speed: 1.0ms preprocess, 19.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.7ms
# Speed: 1.0ms preprocess, 19.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.3ms
# Speed: 1.2ms preprocess, 20.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.8ms
# Speed: 1.0ms preprocess, 18.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.2ms
# Speed: 1.3ms preprocess, 20.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.9ms
# Speed: 1.2ms preprocess, 21.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.0ms
# Speed: 1.3ms preprocess, 19.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.6ms
# Speed: 1.2ms preprocess, 20.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.9ms
# Speed: 1.3ms preprocess, 19.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.7ms
# Speed: 1.3ms preprocess, 19.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.0ms
# Speed: 1.3ms preprocess, 21.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.2ms
# Speed: 1.3ms preprocess, 19.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.2ms
# Speed: 1.3ms preprocess, 25.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.9ms
# Speed: 2.4ms preprocess, 26.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.8ms
# Speed: 1.1ms preprocess, 26.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.8ms
# Speed: 1.1ms preprocess, 26.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.9ms
# Speed: 1.1ms preprocess, 26.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.5ms
# Speed: 1.2ms preprocess, 17.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.5ms
# Speed: 1.2ms preprocess, 19.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 17.9ms
# Speed: 1.2ms preprocess, 17.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.4ms
# Speed: 1.2ms preprocess, 19.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 18.6ms
# Speed: 1.0ms preprocess, 18.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 27.6ms
# Speed: 1.1ms preprocess, 27.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.9ms
# Speed: 1.8ms preprocess, 26.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.9ms
# Speed: 1.1ms preprocess, 26.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 27.0ms
# Speed: 1.1ms preprocess, 27.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 24.8ms
# Speed: 1.1ms preprocess, 24.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 20.6ms
# Speed: 1.2ms preprocess, 20.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.2ms
# Speed: 1.2ms preprocess, 19.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.8ms
# Speed: 1.2ms preprocess, 19.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 27.3ms
# Speed: 1.2ms preprocess, 27.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 20.0ms
# Speed: 1.2ms preprocess, 20.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.9ms
# Speed: 1.2ms preprocess, 19.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.1ms
# Speed: 1.1ms preprocess, 19.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 17.9ms
# Speed: 1.1ms preprocess, 17.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 18.7ms
# Speed: 1.1ms preprocess, 18.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 17.7ms
# Speed: 1.6ms preprocess, 17.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.9ms
# Speed: 1.1ms preprocess, 19.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.2ms
# Speed: 1.6ms preprocess, 26.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 27.2ms
# Speed: 1.8ms preprocess, 27.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.5ms
# Speed: 1.1ms preprocess, 19.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.2ms
# Speed: 1.1ms preprocess, 19.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 17.5ms
# Speed: 1.5ms preprocess, 17.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 22.9ms
# Speed: 1.5ms preprocess, 22.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.2ms
# Speed: 1.1ms preprocess, 26.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.4ms
# Speed: 1.1ms preprocess, 26.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 22.7ms
# Speed: 1.1ms preprocess, 22.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.1ms
# Speed: 1.1ms preprocess, 26.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 27.2ms
# Speed: 1.1ms preprocess, 27.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 25.9ms
# Speed: 1.2ms preprocess, 25.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 27.2ms
# Speed: 1.7ms preprocess, 27.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.5ms
# Speed: 1.1ms preprocess, 26.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 21.6ms
# Speed: 1.1ms preprocess, 21.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 18.9ms
# Speed: 1.0ms preprocess, 18.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.5ms
# Speed: 1.6ms preprocess, 19.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.5ms
# Speed: 1.0ms preprocess, 19.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 20.1ms
# Speed: 1.0ms preprocess, 20.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.3ms
# Speed: 1.0ms preprocess, 19.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 18.9ms
# Speed: 1.0ms preprocess, 18.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.9ms
# Speed: 1.0ms preprocess, 19.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 18.5ms
# Speed: 1.2ms preprocess, 18.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 25.8ms
# Speed: 1.5ms preprocess, 25.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.3ms
# Speed: 1.4ms preprocess, 26.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.4ms
# Speed: 1.7ms preprocess, 26.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.9ms
# Speed: 1.1ms preprocess, 26.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 20.4ms
# Speed: 1.1ms preprocess, 20.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 18.7ms
# Speed: 1.0ms preprocess, 18.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.6ms
# Speed: 1.1ms preprocess, 19.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.1ms
# Speed: 1.1ms preprocess, 19.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 27.8ms
# Speed: 1.2ms preprocess, 27.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.8ms
# Speed: 1.1ms preprocess, 26.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 27.0ms
# Speed: 1.1ms preprocess, 27.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.7ms
# Speed: 1.1ms preprocess, 26.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.5ms
# Speed: 1.1ms preprocess, 27.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.3ms
# Speed: 1.1ms preprocess, 26.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.0ms
# Speed: 1.8ms preprocess, 27.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 27.9ms
# Speed: 1.1ms preprocess, 27.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 28.1ms
# Speed: 1.2ms preprocess, 28.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.9ms
# Speed: 1.1ms preprocess, 26.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 20.7ms
# Speed: 1.5ms preprocess, 20.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.6ms
# Speed: 1.0ms preprocess, 19.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 17.7ms
# Speed: 1.8ms preprocess, 17.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 18.6ms
# Speed: 1.7ms preprocess, 18.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.7ms
# Speed: 1.3ms preprocess, 19.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 25.3ms
# Speed: 1.4ms preprocess, 25.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 22.2ms
# Speed: 2.1ms preprocess, 22.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 20.4ms
# Speed: 1.4ms preprocess, 20.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.4ms
# Speed: 1.3ms preprocess, 19.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 20.8ms
# Speed: 1.3ms preprocess, 20.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.9ms
# Speed: 1.2ms preprocess, 19.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 21.1ms
# Speed: 1.3ms preprocess, 21.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 19.9ms
# Speed: 1.1ms preprocess, 19.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.6ms
# Speed: 1.7ms preprocess, 19.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 20.2ms
# Speed: 1.2ms preprocess, 20.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 18.1ms
# Speed: 1.2ms preprocess, 18.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 20.0ms
# Speed: 1.2ms preprocess, 20.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 18.6ms
# Speed: 1.3ms preprocess, 18.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.3ms
# Speed: 1.0ms preprocess, 19.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Human hands, 19.2ms
# Speed: 1.0ms preprocess, 19.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.0ms
# Speed: 1.2ms preprocess, 19.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Human hands, 20.7ms
# Speed: 1.3ms preprocess, 20.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.4ms
# Speed: 2.1ms preprocess, 19.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 20.1ms
# Speed: 1.3ms preprocess, 20.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.9ms
# Speed: 1.1ms preprocess, 19.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.8ms
# Speed: 1.1ms preprocess, 26.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 29.5ms
# Speed: 1.2ms preprocess, 29.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 21.8ms
# Speed: 1.6ms preprocess, 21.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 20.2ms
# Speed: 0.9ms preprocess, 20.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.6ms
# Speed: 1.4ms preprocess, 19.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 31.4ms
# Speed: 1.1ms preprocess, 31.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 20.9ms
# Speed: 1.3ms preprocess, 20.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 18.6ms
# Speed: 1.2ms preprocess, 18.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.9ms
# Speed: 1.3ms preprocess, 19.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.2ms
# Speed: 0.9ms preprocess, 19.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 20.1ms
# Speed: 1.0ms preprocess, 20.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.3ms
# Speed: 1.0ms preprocess, 19.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.3ms
# Speed: 1.8ms preprocess, 19.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.9ms
# Speed: 1.1ms preprocess, 27.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.8ms
# Speed: 1.2ms preprocess, 26.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 22.3ms
# Speed: 1.2ms preprocess, 22.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.7ms
# Speed: 1.5ms preprocess, 26.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.8ms
# Speed: 1.1ms preprocess, 26.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.9ms
# Speed: 1.0ms preprocess, 26.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.3ms
# Speed: 1.1ms preprocess, 26.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.6ms
# Speed: 1.1ms preprocess, 26.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Human hands, 28.3ms
# Speed: 1.1ms preprocess, 28.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 27.2ms
# Speed: 1.2ms preprocess, 27.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 25.9ms
# Speed: 1.3ms preprocess, 25.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 20.4ms
# Speed: 0.9ms preprocess, 20.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 18.2ms
# Speed: 1.2ms preprocess, 18.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 20.7ms
# Speed: 1.5ms preprocess, 20.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 23.9ms
# Speed: 2.4ms preprocess, 23.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 25.9ms
# Speed: 1.1ms preprocess, 25.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.2ms
# Speed: 1.1ms preprocess, 26.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 27.1ms
# Speed: 1.7ms preprocess, 27.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 27.2ms
# Speed: 1.1ms preprocess, 27.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Human hands, 22.7ms
# Speed: 1.1ms preprocess, 22.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Human hands, 19.2ms
# Speed: 1.0ms preprocess, 19.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Human hands, 18.3ms
# Speed: 1.3ms preprocess, 18.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 20.7ms
# Speed: 1.5ms preprocess, 20.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 18.4ms
# Speed: 1.0ms preprocess, 18.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 19.9ms
# Speed: 1.0ms preprocess, 19.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 18.9ms
# Speed: 0.9ms preprocess, 18.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 20.3ms
# Speed: 1.0ms preprocess, 20.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 18.7ms
# Speed: 1.0ms preprocess, 18.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 18.7ms
# Speed: 1.0ms preprocess, 18.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 18.6ms
# Speed: 1.0ms preprocess, 18.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 20.3ms
# Speed: 1.2ms preprocess, 20.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Human hands, 18.9ms
# Speed: 1.2ms preprocess, 18.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 20.8ms
# Speed: 1.1ms preprocess, 20.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 21.9ms
# Speed: 2.2ms preprocess, 21.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.3ms
# Speed: 1.4ms preprocess, 27.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.9ms
# Speed: 1.2ms preprocess, 26.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.9ms
# Speed: 1.1ms preprocess, 26.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.9ms
# Speed: 1.0ms preprocess, 26.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 29.1ms
# Speed: 1.1ms preprocess, 29.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 28.7ms
# Speed: 1.2ms preprocess, 28.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 29.6ms
# Speed: 1.8ms preprocess, 29.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 24.7ms
# Speed: 1.1ms preprocess, 24.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.2ms
# Speed: 1.7ms preprocess, 19.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.8ms
# Speed: 1.2ms preprocess, 19.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.8ms
# Speed: 1.8ms preprocess, 19.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 25.5ms
# Speed: 1.2ms preprocess, 25.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 21.0ms
# Speed: 1.1ms preprocess, 21.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.7ms
# Speed: 1.2ms preprocess, 19.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.3ms
# Speed: 1.1ms preprocess, 19.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 20.4ms
# Speed: 1.1ms preprocess, 20.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.9ms
# Speed: 1.0ms preprocess, 19.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.6ms
# Speed: 1.0ms preprocess, 19.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 24.4ms
# Speed: 2.0ms preprocess, 24.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 23.1ms
# Speed: 1.2ms preprocess, 23.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 20.7ms
# Speed: 1.4ms preprocess, 20.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 18.7ms
# Speed: 1.0ms preprocess, 18.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 18.8ms
# Speed: 1.1ms preprocess, 18.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 20.1ms
# Speed: 1.0ms preprocess, 20.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 20.2ms
# Speed: 1.0ms preprocess, 20.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 18.6ms
# Speed: 1.3ms preprocess, 18.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.5ms
# Speed: 1.2ms preprocess, 19.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.9ms
# Speed: 1.0ms preprocess, 19.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 20.1ms
# Speed: 1.0ms preprocess, 20.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 18.1ms
# Speed: 1.0ms preprocess, 18.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.4ms
# Speed: 1.1ms preprocess, 27.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 28.1ms
# Speed: 1.1ms preprocess, 28.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.0ms
# Speed: 1.1ms preprocess, 26.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.6ms
# Speed: 1.3ms preprocess, 26.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.3ms
# Speed: 1.1ms preprocess, 26.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.1ms
# Speed: 1.3ms preprocess, 27.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.8ms
# Speed: 1.1ms preprocess, 27.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 28.6ms
# Speed: 1.6ms preprocess, 28.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 31.0ms
# Speed: 1.1ms preprocess, 31.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 28.3ms
# Speed: 1.7ms preprocess, 28.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.3ms
# Speed: 1.2ms preprocess, 27.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.3ms
# Speed: 1.1ms preprocess, 27.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 20.9ms
# Speed: 1.1ms preprocess, 20.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 28.9ms
# Speed: 1.4ms preprocess, 28.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 28.0ms
# Speed: 1.1ms preprocess, 28.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 20.9ms
# Speed: 1.1ms preprocess, 20.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 20.9ms
# Speed: 1.1ms preprocess, 20.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 20.3ms
# Speed: 1.6ms preprocess, 20.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 20.0ms
# Speed: 1.5ms preprocess, 20.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.2ms
# Speed: 1.5ms preprocess, 19.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 20.2ms
# Speed: 1.2ms preprocess, 20.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 20.6ms
# Speed: 1.0ms preprocess, 20.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.7ms
# Speed: 1.0ms preprocess, 19.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 20.3ms
# Speed: 1.0ms preprocess, 20.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.5ms
# Speed: 1.8ms preprocess, 19.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.7ms
# Speed: 1.1ms preprocess, 19.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.2ms
# Speed: 1.2ms preprocess, 19.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.9ms
# Speed: 1.2ms preprocess, 19.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 31.4ms
# Speed: 1.5ms preprocess, 31.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.5ms
# Speed: 1.5ms preprocess, 19.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.2ms
# Speed: 1.0ms preprocess, 19.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 20.5ms
# Speed: 1.5ms preprocess, 20.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.5ms
# Speed: 1.1ms preprocess, 19.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 28.1ms
# Speed: 1.5ms preprocess, 28.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.1ms
# Speed: 1.2ms preprocess, 27.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.2ms
# Speed: 1.1ms preprocess, 27.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.2ms
# Speed: 1.2ms preprocess, 27.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.3ms
# Speed: 1.4ms preprocess, 27.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.7ms
# Speed: 1.3ms preprocess, 26.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.6ms
# Speed: 1.1ms preprocess, 26.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.2ms
# Speed: 1.1ms preprocess, 27.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.2ms
# Speed: 1.1ms preprocess, 27.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.1ms
# Speed: 1.1ms preprocess, 26.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.4ms
# Speed: 1.1ms preprocess, 26.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 27.0ms
# Speed: 1.1ms preprocess, 27.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.3ms
# Speed: 1.1ms preprocess, 27.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.7ms
# Speed: 1.3ms preprocess, 26.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 22.6ms
# Speed: 1.1ms preprocess, 22.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 27.5ms
# Speed: 1.1ms preprocess, 27.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.2ms
# Speed: 1.2ms preprocess, 19.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 20.8ms
# Speed: 1.0ms preprocess, 20.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.5ms
# Speed: 1.2ms preprocess, 19.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 21.1ms
# Speed: 1.3ms preprocess, 21.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.4ms
# Speed: 1.0ms preprocess, 19.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.8ms
# Speed: 1.0ms preprocess, 19.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 20.0ms
# Speed: 1.2ms preprocess, 20.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 19.1ms
# Speed: 1.3ms preprocess, 19.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 22.9ms
# Speed: 1.5ms preprocess, 22.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 20.1ms
# Speed: 1.2ms preprocess, 20.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.8ms
# Speed: 1.1ms preprocess, 26.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 28.6ms
# Speed: 1.1ms preprocess, 28.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 28.6ms
# Speed: 1.6ms preprocess, 28.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.1ms
# Speed: 1.7ms preprocess, 26.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.6ms
# Speed: 1.0ms preprocess, 26.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.6ms
# Speed: 1.1ms preprocess, 26.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.6ms
# Speed: 1.2ms preprocess, 26.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.0ms
# Speed: 1.1ms preprocess, 26.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.6ms
# Speed: 1.1ms preprocess, 26.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 27.1ms
# Speed: 1.1ms preprocess, 27.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.8ms
# Speed: 1.2ms preprocess, 19.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 22.5ms
# Speed: 1.3ms preprocess, 22.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.9ms
# Speed: 1.0ms preprocess, 19.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.3ms
# Speed: 1.2ms preprocess, 19.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 20.6ms
# Speed: 1.0ms preprocess, 20.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 25.9ms
# Speed: 1.1ms preprocess, 25.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.7ms
# Speed: 1.1ms preprocess, 27.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.9ms
# Speed: 1.1ms preprocess, 26.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 31.1ms
# Speed: 1.4ms preprocess, 31.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.9ms
# Speed: 1.1ms preprocess, 26.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.3ms
# Speed: 1.1ms preprocess, 26.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 27.0ms
# Speed: 1.1ms preprocess, 27.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.5ms
# Speed: 1.1ms preprocess, 26.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.5ms
# Speed: 1.1ms preprocess, 26.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.8ms
# Speed: 1.4ms preprocess, 26.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.5ms
# Speed: 1.1ms preprocess, 26.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.0ms
# Speed: 1.1ms preprocess, 26.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.9ms
# Speed: 1.3ms preprocess, 26.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.4ms
# Speed: 1.0ms preprocess, 19.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 21.2ms
# Speed: 1.4ms preprocess, 21.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 19.9ms
# Speed: 1.4ms preprocess, 19.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 22.7ms
# Speed: 1.3ms preprocess, 22.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 20.9ms
# Speed: 1.0ms preprocess, 20.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 32.2ms
# Speed: 1.4ms preprocess, 32.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 28.6ms
# Speed: 1.7ms preprocess, 28.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 28.1ms
# Speed: 1.1ms preprocess, 28.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 27.6ms
# Speed: 1.1ms preprocess, 27.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 29.2ms
# Speed: 1.1ms preprocess, 29.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 27.9ms
# Speed: 1.1ms preprocess, 27.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 28.6ms
# Speed: 1.1ms preprocess, 28.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 30.3ms
# Speed: 1.1ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 28.5ms
# Speed: 1.6ms preprocess, 28.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 20.6ms
# Speed: 1.0ms preprocess, 20.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 20.1ms
# Speed: 1.0ms preprocess, 20.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 25.8ms
# Speed: 1.2ms preprocess, 25.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 27.1ms
# Speed: 1.1ms preprocess, 27.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 25.8ms
# Speed: 1.1ms preprocess, 25.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 20.1ms
# Speed: 1.0ms preprocess, 20.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 20.2ms
# Speed: 1.1ms preprocess, 20.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 22.7ms
# Speed: 1.5ms preprocess, 22.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 29.3ms
# Speed: 1.3ms preprocess, 29.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 22.8ms
# Speed: 1.1ms preprocess, 22.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 20.1ms
# Speed: 1.0ms preprocess, 20.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.9ms
# Speed: 1.0ms preprocess, 19.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.9ms
# Speed: 1.0ms preprocess, 19.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.4ms
# Speed: 1.0ms preprocess, 19.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 18.8ms
# Speed: 1.2ms preprocess, 18.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 20.4ms
# Speed: 1.5ms preprocess, 20.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 20.6ms
# Speed: 1.2ms preprocess, 20.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 20.0ms
# Speed: 1.2ms preprocess, 20.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.2ms
# Speed: 1.2ms preprocess, 19.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.3ms
# Speed: 1.2ms preprocess, 19.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.6ms
# Speed: 1.0ms preprocess, 19.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.6ms
# Speed: 1.4ms preprocess, 19.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.2ms
# Speed: 1.4ms preprocess, 19.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.7ms
# Speed: 1.1ms preprocess, 27.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.6ms
# Speed: 1.1ms preprocess, 26.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 29.3ms
# Speed: 1.2ms preprocess, 29.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.2ms
# Speed: 1.1ms preprocess, 27.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.4ms
# Speed: 1.1ms preprocess, 26.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 27.0ms
# Speed: 1.1ms preprocess, 27.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 27.2ms
# Speed: 2.2ms preprocess, 27.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.1ms
# Speed: 1.1ms preprocess, 26.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 25.8ms
# Speed: 1.1ms preprocess, 25.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 22.6ms
# Speed: 1.2ms preprocess, 22.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 21.7ms
# Speed: 1.1ms preprocess, 21.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 22.5ms
# Speed: 1.3ms preprocess, 22.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 23.0ms
# Speed: 1.3ms preprocess, 23.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.9ms
# Speed: 1.1ms preprocess, 26.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 27.1ms
# Speed: 1.1ms preprocess, 27.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.0ms
# Speed: 1.2ms preprocess, 26.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 25.3ms
# Speed: 1.1ms preprocess, 25.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 29.8ms
# Speed: 1.1ms preprocess, 29.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 29.1ms
# Speed: 1.6ms preprocess, 29.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.8ms
# Speed: 1.7ms preprocess, 26.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.2ms
# Speed: 1.2ms preprocess, 27.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 28.6ms
# Speed: 1.1ms preprocess, 28.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 28.4ms
# Speed: 1.1ms preprocess, 28.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.1ms
# Speed: 1.1ms preprocess, 27.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.0ms
# Speed: 1.1ms preprocess, 26.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.7ms
# Speed: 1.8ms preprocess, 26.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Human hands, 25.4ms
# Speed: 1.1ms preprocess, 25.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.0ms
# Speed: 1.6ms preprocess, 26.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.1ms
# Speed: 1.1ms preprocess, 26.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.2ms
# Speed: 1.7ms preprocess, 26.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.6ms
# Speed: 1.1ms preprocess, 26.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.7ms
# Speed: 1.1ms preprocess, 26.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 32.4ms
# Speed: 1.1ms preprocess, 32.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 28.2ms
# Speed: 1.1ms preprocess, 28.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 27.9ms
# ...
#
# 0: 384x640 1 Human hand, 26.6ms
# Speed: 1.1ms preprocess, 26.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.8ms
# Speed: 1.1ms preprocess, 26.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.9ms
# Speed: 1.1ms preprocess, 26.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.7ms
# Speed: 1.0ms preprocess, 26.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 25.7ms
# Speed: 1.2ms preprocess, 25.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.7ms
# Speed: 1.0ms preprocess, 19.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 19.3ms
# Speed: 1.2ms preprocess, 19.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 18.7ms
# Speed: 1.0ms preprocess, 18.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 17.8ms
# Speed: 1.0ms preprocess, 17.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 18.8ms
# Speed: 1.0ms preprocess, 18.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 25.9ms
# Speed: 1.3ms preprocess, 25.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 27.1ms
# Speed: 1.4ms preprocess, 27.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.2ms
# Speed: 1.1ms preprocess, 26.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.1ms
# Speed: 1.1ms preprocess, 27.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.7ms
# Speed: 1.1ms preprocess, 26.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.7ms
# Speed: 1.1ms preprocess, 26.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Human hand, 26.4ms
# Speed: 1.2ms preprocess, 26.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 29.2ms
# Speed: 1.2ms preprocess, 29.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.9ms
# Speed: 1.1ms preprocess, 26.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.6ms
# Speed: 1.1ms preprocess, 27.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 29.9ms
# Speed: 1.6ms preprocess, 29.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.1ms
# Speed: 1.1ms preprocess, 27.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.4ms
# Speed: 1.1ms preprocess, 26.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.0ms
# Speed: 1.1ms preprocess, 27.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.3ms
# Speed: 1.7ms preprocess, 26.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.8ms
# Speed: 1.1ms preprocess, 26.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.8ms
# Speed: 1.1ms preprocess, 26.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.9ms
# Speed: 1.1ms preprocess, 26.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 27.5ms
# Speed: 1.3ms preprocess, 27.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 27.4ms
# Speed: 1.1ms preprocess, 27.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 27.9ms
# Speed: 1.1ms preprocess, 27.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.9ms
# Speed: 1.2ms preprocess, 26.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 27.2ms
# Speed: 1.1ms preprocess, 27.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.3ms
# Speed: 1.1ms preprocess, 27.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.7ms
# Speed: 1.1ms preprocess, 26.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.6ms
# Speed: 1.1ms preprocess, 26.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 27.5ms
# Speed: 1.1ms preprocess, 27.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 27.9ms
# Speed: 1.1ms preprocess, 27.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.8ms
# Speed: 1.3ms preprocess, 27.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.8ms
# Speed: 1.1ms preprocess, 26.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.4ms
# Speed: 1.1ms preprocess, 27.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 28.1ms
# Speed: 1.1ms preprocess, 28.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Human hands, 26.9ms
# Speed: 1.3ms preprocess, 26.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 27.1ms
# Speed: 1.0ms preprocess, 27.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Human hands, 27.1ms
# Speed: 1.1ms preprocess, 27.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.8ms
# Speed: 1.1ms preprocess, 26.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.9ms
# Speed: 1.1ms preprocess, 26.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.2ms
# Speed: 1.2ms preprocess, 26.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.8ms
# Speed: 1.1ms preprocess, 26.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 25.8ms
# Speed: 1.1ms preprocess, 25.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.6ms
# Speed: 1.1ms preprocess, 26.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.5ms
# Speed: 1.1ms preprocess, 26.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.6ms
# Speed: 1.1ms preprocess, 26.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.1ms
# Speed: 1.1ms preprocess, 26.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 27.2ms
# Speed: 1.0ms preprocess, 27.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.2ms
# Speed: 1.1ms preprocess, 26.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 29.2ms
# Speed: 1.1ms preprocess, 29.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.3ms
# Speed: 1.2ms preprocess, 26.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 28.6ms
# Speed: 1.2ms preprocess, 28.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.7ms
# Speed: 1.1ms preprocess, 26.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.5ms
# Speed: 1.2ms preprocess, 26.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.5ms
# Speed: 1.2ms preprocess, 26.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.6ms
# Speed: 1.0ms preprocess, 26.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.7ms
# Speed: 1.1ms preprocess, 26.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.6ms
# Speed: 1.1ms preprocess, 26.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Human hands, 26.6ms
# Speed: 1.1ms preprocess, 26.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 27.6ms
# Speed: 1.2ms preprocess, 27.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Human hands, 26.0ms
# Speed: 1.1ms preprocess, 26.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.2ms
# Speed: 1.1ms preprocess, 26.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.4ms
# Speed: 1.1ms preprocess, 26.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.5ms
# Speed: 1.1ms preprocess, 26.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 27.1ms
# Speed: 1.2ms preprocess, 27.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.3ms
# Speed: 1.1ms preprocess, 27.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.0ms
# Speed: 1.1ms preprocess, 26.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 25.6ms
# Speed: 1.1ms preprocess, 25.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 28.6ms
# Speed: 1.2ms preprocess, 28.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.1ms
# Speed: 1.0ms preprocess, 27.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.7ms
# Speed: 1.0ms preprocess, 27.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.5ms
# Speed: 1.1ms preprocess, 27.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.0ms
# Speed: 1.1ms preprocess, 27.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.1ms
# Speed: 1.9ms preprocess, 27.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 25.8ms
# Speed: 1.0ms preprocess, 25.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.3ms
# Speed: 1.1ms preprocess, 27.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.1ms
# Speed: 1.1ms preprocess, 27.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.0ms
# Speed: 1.1ms preprocess, 27.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.4ms
# Speed: 1.1ms preprocess, 26.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.1ms
# Speed: 1.0ms preprocess, 27.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.3ms
# Speed: 1.0ms preprocess, 26.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 25.4ms
# Speed: 1.1ms preprocess, 25.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 26.9ms
# Speed: 1.1ms preprocess, 26.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.5ms
# Speed: 1.1ms preprocess, 26.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.9ms
# Speed: 1.1ms preprocess, 26.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Human hands, 25.6ms
# Speed: 1.1ms preprocess, 25.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Human hands, 27.4ms
# Speed: 1.2ms preprocess, 27.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Human hands, 27.3ms
# Speed: 1.0ms preprocess, 27.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Human hands, 27.3ms
# Speed: 1.2ms preprocess, 27.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.5ms
# Speed: 1.1ms preprocess, 26.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.4ms
# Speed: 1.1ms preprocess, 26.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.3ms
# Speed: 1.1ms preprocess, 26.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 26.9ms
# Speed: 1.2ms preprocess, 26.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 25.5ms
# Speed: 1.1ms preprocess, 25.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 25.8ms
# Speed: 1.1ms preprocess, 25.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Human hands, 27.0ms
# Speed: 1.3ms preprocess, 27.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Human hands, 27.0ms
# Speed: 1.1ms preprocess, 27.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Human hands, 30.2ms
# Speed: 1.2ms preprocess, 30.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Human hands, 26.3ms
# Speed: 1.0ms preprocess, 26.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Human hands, 25.8ms
# Speed: 1.1ms preprocess, 25.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Human hands, 26.5ms
# Speed: 1.1ms preprocess, 26.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Human hands, 26.7ms
# Speed: 1.0ms preprocess, 26.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Human hands, 26.7ms
# Speed: 1.0ms preprocess, 26.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Human hands, 26.1ms
# Speed: 1.0ms preprocess, 26.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Human hands, 26.3ms
# Speed: 1.1ms preprocess, 26.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Human hands, 26.4ms
# Speed: 1.1ms preprocess, 26.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Human hands, 25.9ms
# Speed: 1.1ms preprocess, 25.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Human hands, 19.6ms
# Speed: 1.2ms preprocess, 19.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Human hands, 18.8ms
# Speed: 1.2ms preprocess, 18.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Human hands, 20.3ms
# Speed: 1.2ms preprocess, 20.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Human hands, 19.1ms
# Speed: 1.2ms preprocess, 19.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Human hands, 26.9ms
# Speed: 1.1ms preprocess, 26.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Human hands, 26.9ms
# Speed: 1.1ms preprocess, 26.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Human hands, 21.8ms
# Speed: 1.1ms preprocess, 21.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
